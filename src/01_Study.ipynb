# %% [markdown]
# # Day1 2025.11.21

# %% [markdown]
# 🎯 문제 1: "안녕" 5번 출력하기
# 가장 기본적인 반복 연습입니다.
#
# 요구사항: 화면에 "안녕!" 이라는 글자를 총 5번 출력하는 for문을 작성하세요.

# %%
answer = "안녕!"

for i in answer:
    print(i * 5)
# Out:
# Running cells with 'EveryDayStudy (Python 3.11.13)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/POTENUP/EveryDayStudy/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
